# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load HR Dataset

# %%
hr_data = pd.read_csv("C:/Users/EGO/Desktop/MeriSkill/Project 3 - HR Analytics/HR-Employee-Attrition.csv")

# %% [markdown]
# View the first 5 rows

# %%
hr_data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# Get the statistics

# %%
hr_data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Check data type

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Check for missing values

# %%
hr_data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Deleting Reduntant Columns

# %%
col_to_del = ['Attrition','Over18', 'EmployeeCount', 'StandardHours']
hr_data.drop(col_to_del, axis = 1, inplace = True)

# %%
hr_data.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  Gender  ...  PerformanceRating  \
# 0                        2  Female  ...                  3
# 1                        3    Male  ...                  4
# ...

# %% [markdown]
# Deleting Duplicates

# %%
# Count rows before deleting duplicates
rows_before = len(hr_data)

# Remove duplicates and keep the first occurrence
hr_data_no_duplicates = hr_data.drop_duplicates()

# Count rows after deleting duplicates
rows_after = len(hr_data_no_duplicates)

print(f"Rows before: {rows_before}")
print(f"Rows after: {rows_after}")
# Out:
# Rows before: 1470
# Rows after: 1470

# %% [markdown]
# Correlation map for all numeric variables

# %%
numeric_columns = hr_data.select_dtypes(include=['number'])
correlation_matrix = numeric_columns.corr()

# %%
plt.figure(figsize=(17, 15))
sns.heatmap(correlation_matrix, annot=True, cmap="seismic", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# Create a pie for Overtime
Overtime_counts = hr_data['OverTime'].value_counts()
plt.pie(Overtime_counts, labels=Overtime_counts.index, autopct='%1.1f%%', colors=['skyblue', 'darkblue'])
plt.title('Pie Chart for a OverTime')
plt.show()

# %%
# Marital Status of employees
status_counts = hr_data['MaritalStatus'].value_counts()

plt.figure(figsize=(6, 4)),
plt.bar(status_counts.index, status_counts.values, color='darkblue'),
plt.xlabel('MaritalStatus'),
plt.ylabel('Values'),
plt.title('Distribution of Marital Status'),
plt.show()

# %%
# Roles of employees
jobrole_counts = hr_data['JobRole'].value_counts()

plt.figure(figsize=(6, 4))
plt.barh(jobrole_counts.index, jobrole_counts.values, color='darkblue')
plt.xlabel('No. of employees')
plt.title('Distribution of Job Role')
plt.show()

# %%
# Create a pie for gender
gender_counts = hr_data['Gender'].value_counts()

plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=['darkblue', 'skyblue'])
plt.title('Distribution of Gender')
plt.show()

# %%
# Field of study

educationfield_counts = hr_data['EducationField'].value_counts()

plt.figure(figsize=(6, 4))
plt.barh(educationfield_counts.index, educationfield_counts.values, color='darkblue')
plt.xlabel('Number of Employees')
plt.title('Distribution of Education Field')
plt.show()

# %%
#Visualization to ascertain number of employees in the different department
dept_counts = hr_data['Department'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(dept_counts.index, dept_counts.values, color='darkblue')
plt.ylabel('Number of Employees')
plt.title('Distribution of Department')
plt.show()

# %%
#Graph showing copany sponsored travels

biz_travels_counts = hr_data['BusinessTravel'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(biz_travels_counts.index, biz_travels_counts.values, color='darkblue')
plt.ylabel('Number of Employees')
plt.title('Distribution of Business Travel')
plt.show()

# %%
# Create a grouped bar chart to check the relationship between overtime and age
plt.figure(figsize=(8, 6))
sns.boxplot(data=hr_data, x='OverTime', y='Age', palette='Set1')
plt.title('Relationship Between Overtime and Age')
plt.show()

# %%
#Number of years an employee has worked
plt.figure(figsize=(6, 4))
plt.hist(hr_data['TotalWorkingYears'],bins=10, color='darkblue', edgecolor='black')
plt.xlabel('Sum of working Years')
plt.ylabel('Frequency')
plt.title('Total Working Years')
plt.show()

# %%
# Education level of the employees 1 being basic
edu_counts = hr_data['Education'].value_counts()
plt.figure(figsize=(6, 4))
plt.bar(edu_counts.index, edu_counts.values, color='darkblue')
plt.xlabel('Levels')
plt.ylabel('Number of Employees')
plt.title('Education Level')
plt.show()

# %%
# Number of companies employee worked
no_coy_worked = hr_data['NumCompaniesWorked'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(no_coy_worked.index, no_coy_worked.values, color='darkblue')
plt.xlabel('No. of Companies')
plt.ylabel('Number of Employees')
plt.title('Number of Companies Worked')
plt.show()

# %%
#Visualization showing distance from home
plt.figure(figsize=(6, 4))
plt.hist(hr_data['DistanceFromHome'],bins=15, color='darkblue', edgecolor='black')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.title('Distance From Home')
plt.show()

# %% [markdown]
# Design a dashboard showing all graphs

# %%
# Create a figure for the dashboard
fig, axes = plt.subplots(4, 4, figsize=(20, 20))

# Pie Chart
Overtime_counts = hr_data['OverTime'].value_counts()
axes[0,0].pie(Overtime_counts, labels=Overtime_counts.index, autopct='%1.1f%%', colors=['skyblue', 'darkblue'])
axes[0,0].set_title('Over Time')



Gender_counts = hr_data['Gender'].value_counts()
axes[0,1].pie(Gender_counts, labels = Gender_counts.index, autopct='%1.1f%%', colors=['skyblue', 'darkblue'])
axes[0,1].set_title('Distribution of gender')


# Bar Graph
sns.countplot(data=hr_data, x='MaritalStatus', color='darkblue',ax=axes[0,2])
axes[0, 2].set_title('Marital Status')

sns.countplot(data=hr_data, x='JobRole'color='darkblue',ax=axes[0,2])
axes[0, 2].set_title('Marital Status')

sns.countplot(data=hr_data, x='Department',color='darkblue',ax=axes[0, 3])
axes[0,2].set_title('Department')

 
sns.countplot(data = hr_data, y = 'EducationField', color='darkblue', ax=axes[1,0])
axes[1, 0].set_title('Education Field')

sns.countplot(data=hr_data,y='BusinessTravel',color='darkblue', ax=axes[1, 0])
axes[1, 0].set_title('Business Travel')

sns.countplot(data = hr_data, x = 'Education', color='darkblue', ax=axes[1, 1])
axes[1, 1].set_title('Level of Education')


sns.countplot(data = hr_data, x = 'NumCompaniesWorked', color = 'darkblue', ax= axes[1, 2])
axes[1, 2].set_title('No. of Companies Worked')

sns.histplot(data=hr_data,
             x='TotalWorkingYears', y='Frequency', color='darkblue', ax=axes[1, 3]
)
# Adjust layout
plt.tight_layout()

# Save or display the figure
# plt.savefig('dashboard.png')
plt.show()
This code combines the visualizations into a single dashboard. You can choose to save the figure as an image or display it in your Jupyter Notebook.

Remember to adapt the code to your dataset and specific requirements, including variable names, color choices, and figure sizes.
# Out:
#   Cell In[102], line 46
#     This code combines the visualizations into a single dashboard. You can choose to save the figure as an image or display it in your Jupyter Notebook.
#          ^
# SyntaxError: invalid syntax

# %%
# Create a figure for the dashboard
fig, axes = plt.subplots(4, 3, figsize=(20, 30))

# Pie Chart
Overtime_counts = hr_data['OverTime'].value_counts()
axes[0,0].pie(Overtime_counts, labels=Overtime_counts.index, autopct='%1.1f%%', colors=['skyblue', 'darkblue'])
axes[0,0].set_title('Over Time')

Gender_counts = hr_data['Gender'].value_counts()
axes[0,2].pie(Gender_counts, labels = Gender_counts.index, autopct='%1.1f%%', colors=['skyblue', 'darkblue'])
axes[0,2].set_title('Distribution of gender')

# Bar Graph
sns.countplot(data=hr_data, x='MaritalStatus', color='darkblue',ax=axes[0, 1])
axes[0, 1].set_title('Marital Status')

sns.countplot(data=hr_data, y='JobRole', color='darkblue',ax=axes[1 ,0])
axes[1, 0].set_title('Job Role')

sns.countplot(data=hr_data, x='Department',color='darkblue',ax=axes[2, 0])
axes[2, 0].set_title('Department')

sns.countplot(data = hr_data, y = 'EducationField', color='darkblue', ax=axes[1, 2])
axes[1, 2].set_title('Education Field')

sns.countplot(data=hr_data,y='BusinessTravel',color='darkblue', ax=axes[1, 1])
axes[1, 1].set_title('Business Travel')

sns.countplot(data = hr_data, x = 'Education', color='darkblue', ax=axes[2, 2])
axes[2, 2].set_title('Level of Education')

sns.countplot(data = hr_data, x = 'NumCompaniesWorked', color = 'darkblue', ax= axes[2, 1])
axes[2, 1].set_title('No. of Companies Worked')

sns.histplot(data=hr_data, x='TotalWorkingYears',bins = 10, color='darkblue', ax=axes[3, 0])
axes[3, 0].set_title('Working Years')

sns.histplot(data=hr_data, x='DistanceFromHome',bins = 10, color='darkblue', ax=axes[3, 2])
axes[3, 2].set_title('Distance From Home')

sns.boxplot(data=hr_data, x='OverTime', y='Age', color='darkblue',ax=axes[3, 1])
axes[3, 1].set_title('Relationship Between Overtime and Age')
 

# Adjust layout
plt.tight_layout()

# Save or display the figure
plt.savefig('HR dashboard.png')
plt.show()
